# %%
from sklearn import tree

# %%
data_to_train = [[150, 1],
                 [170, 1],
                [90, 0],
                [70, 0]]
labels = ["apple", "apple", "orang", "orang"]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(data_to_train, labels)
clf.predict([[200, 0],[150,0],[50,1],[70,1]])
# Out:
# array(['apple', 'apple', 'orang', 'orang'], dtype='<U5')

# %%
from sklearn.tree import plot_tree
plot_tree(clf, feature_names=["weight", "color"], class_names=["apple", "orange"], filled=True)
# Out:
# [Text(0.5, 0.75, 'weight <= 120.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple')]
