# %%
import numpy as np
import random
import pandas
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(0,1,100000000)
plt.hist(data, bins=50)
# Out:
# (array([1997282., 1998418., 2000149., 2000171., 2000774., 2001250.,
#         2002014., 1998751., 1998928., 2001527., 1999898., 1999341.,
#         2000720., 2001695., 2000947., 1997476., 1999919., 1999183.,
#         2001299., 2000839., 1999655., 2001837., 2001705., 1999396.,
#         1999940., 1998669., 2001058., 1998956., 1997774., 1999300.,
#         2000895., 1999368., 2000568., 1998991., 1998506., 1999352.,
#         2001580., 2001062., 2000402., 1998560., 2002268., 1998517.,
#         1999970., 2001065., 1998820., 2000079., 2001339., 1999591.,
#         1997668., 2002528.]),
#  array([6.24649665e-10, 2.00000003e-02, 4.00000001e-02, 5.99999998e-02,
#         7.99999995e-02, 9.99999992e-02, 1.19999999e-01, 1.39999999e-01,
#         1.59999998e-01, 1.79999998e-01, 1.99999998e-01, 2.19999998e-01,
#         2.39999997e-01, 2.59999997e-01, 2.79999997e-01, 2.99999996e-01,
#         3.19999996e-01, 3.39999996e-01, 3.59999996e-01, 3.79999995e-01,
# ...

# %%
from scipy.stats import binom, norm

# %%
p = binom.pmf(k=10, n=10, p=0.5)
print(p)
# Out:
# 0.0009765625

# %%
data = np.linspace(50,80, 1000)
mean = 65
std_dev= 3
plotingdata = norm.pdf(data, loc=mean, scale=std_dev)
plt.plot(data, plotingdata)
