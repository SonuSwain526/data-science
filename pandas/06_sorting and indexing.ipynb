# %%
import pandas as pd

# %%
df = pd.read_csv("df2 cleaned data.csv")

# %%
df
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8       8                              Webcam Stove Grill
# 9      10               Ultra Powerbank Brush Charger Max
# 10     10               Ultra Powerbank Brush Charger Max
# 11     11                                   Wireless Dock
# 12     13                                    Heater Radio
# 13     13                                    Heater Radio
# 14     14                     Smart Trimmer Webcam Heater
# ...

# %% [raw]
# sorting by values

# %%
# df.sort_values('Stock')
# df.sort_values('Stock', ascending=False)
df.sort_values(['Stock', 'Price']) #basically we sort here stock clm but the work of price is if there is any tie in Stock clm it will sort accroding to Price clm
# Out:
#     Index                                            Name  \
# 16     17                            Eco Iron Monitor Air
# 1       2                                          Tablet
# 2       2                                          Tablet
# 12     13                                    Heater Radio
# 13     13                                    Heater Radio
# 15     15                              Webcam Dock Heater
# 11     11                                   Wireless Dock
# 6       6                                           Radio
# 10     10               Ultra Powerbank Brush Charger Max
# 8       8                              Webcam Stove Grill
# 19     19                     Eco Freezer Powerbank Watch
# 3       3                            Smart Blender Cooker
# 18     18              Digital Tablet Router Printer Lite
# 0       1            Compact Printer Air Advanced Digital
# 17      1            Compact Printer Air Advanced Digital
# ...

# %% [raw]
# Indexing reset

# %%
# df.reset_index()
# df.reset_index(drop = True)
df.reset_index(drop = True, inplace=True)

# %%
df
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8       8                              Webcam Stove Grill
# 9      10               Ultra Powerbank Brush Charger Max
# 10     10               Ultra Powerbank Brush Charger Max
# 11     11                                   Wireless Dock
# 12     13                                    Heater Radio
# 13     13                                    Heater Radio
# 14     14                     Smart Trimmer Webcam Heater
# ...

# %% [raw]
# sorting index

# %%
df.sort_index()
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8       8                              Webcam Stove Grill
# 9      10               Ultra Powerbank Brush Charger Max
# 10     10               Ultra Powerbank Brush Charger Max
# 11     11                                   Wireless Dock
# 12     13                                    Heater Radio
# 13     13                                    Heater Radio
# 14     14                     Smart Trimmer Webcam Heater
# ...

# %% [raw]
# Adding a clm called it is rank based on the clm that we give ot it

# %%
# df["Rank by Price"] = df["Stock"].rank()
df["Rank by Price"] = df["Stock"].rank(ascending=False, method="dense") #ascending means it

# %%
df
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8       8                              Webcam Stove Grill
# 9      10               Ultra Powerbank Brush Charger Max
# 10     10               Ultra Powerbank Brush Charger Max
# 11     11                                   Wireless Dock
# 12     13                                    Heater Radio
# 13     13                                    Heater Radio
# 14     14                     Smart Trimmer Webcam Heater
# ...

# %% [raw]
# renaming columns and index

# %%
df.rename(columns={"Name" : "Product Nmae", "Category" : "Type"})
df.rename(index={0: "Row1", 1: "Row2"})
# Out:
#       Index                                            Name  \
# Row1      1            Compact Printer Air Advanced Digital
# Row2      2                                          Tablet
# 2         2                                          Tablet
# 3         3                            Smart Blender Cooker
# 4         4                    Advanced Router Rechargeable
# 5         5                    Portable Mouse Monitor Phone
# 6         6                                           Radio
# 7         7  Ultra Projector Oven Thermostat Prime Advanced
# 8         8                              Webcam Stove Grill
# 9        10               Ultra Powerbank Brush Charger Max
# 10       10               Ultra Powerbank Brush Charger Max
# 11       11                                   Wireless Dock
# 12       13                                    Heater Radio
# 13       13                                    Heater Radio
# 14       14                     Smart Trimmer Webcam Heater
# ...
