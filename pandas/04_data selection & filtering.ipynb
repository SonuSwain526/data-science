# %%
import pandas as pd

# %%
df = pd.read_csv("customers-100.csv")

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df["Customer Id"][1]
df["Customer Id"][1:4]
df[["Customer Id", "Company"]][1:5].copy()
# Out:
#        Customer Id                          Company
# 1  1Ef7b82A4CAAD10                      Vega-Gentry
# 2  6F94879bDAfE5a6                    Murillo-Perry
# 3  5Cef8BFA16c5e3c  Dominguez, Mcmillan and Donovan
# 4  053d585Ab6b3159         Martin, Lang and Andrade

# %% [markdown]
# slecting rows by loc

# %%
df.loc[1]
df.loc[1]["Company"] #or we can also write
df.loc[1, "Company"]
# Out:
# 'Vega-Gentry'

# %% [markdown]
# slicing by loc

# %%
df.loc[1:4, ["Company", "Customer Id"]]
# Out:
#                            Company      Customer Id
# 1                      Vega-Gentry  1Ef7b82A4CAAD10
# 2                    Murillo-Perry  6F94879bDAfE5a6
# 3  Dominguez, Mcmillan and Donovan  5Cef8BFA16c5e3c
# 4         Martin, Lang and Andrade  053d585Ab6b3159

# %% [markdown]
# selecting rows by iloc

# %%
df.iloc[1,2]
# Out:
# 'Preston'

# %% [markdown]
# slicing by iloc

# %%
df.iloc[30:40, 1:4]
# Out:
#         Customer Id First Name Last Name
# 30  64DCcDFaB9DFd4e       Jack      Tate
# 31  679c6c83DD872d6        Tom  Trujillo
# 32  7Ce381e4Afa4ba9    Gabriel     Mejia
# 33  A09AEc6E3bF70eE    Kaitlyn   Santana
# 34  aA9BAFfBc3710fe      Faith      Moon
# 35  E11dfb2DB8C9f72     Tammie     Haley
# 36  889eCf90f68c5Da   Nicholas      Sosa
# 37  7a1Ee69F4fF4B4D     Jordan       Gay
# 38  dca4f1D0A0fc5c9      Bruce   Esparza
# 39  17aD8e2dB3df03D     Sherry     Garza

# %% [markdown]
# selecting by at and iat *for only a single element

# %%
df.at[2, "Company"]
df.iat[2,8]
# Out:
# '(496)978-3969x58947'

# %% [markdown]
# filtering by condition

# %%
# print(df[df['Index'] > 90])
print(df[(df['Index'] > 93) & (df['City'] == "Daisyborough")])
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
#
#             City Country                Phone 1           Phone 2  \
# 94  Daisyborough    Mali  001-084-845-9524x1777  001-769-564-6303
#
#                        Email Subscription Date             Website
# 94  grayjean@lowery-good.com        2022-02-17  https://banks.biz/

# %% [raw]
# filtering by quary

# %%
df.query("Index > 93")
df.query("Index > 93 and City == 'Daisyborough'")
# Out:
#     Index      Customer Id First Name Last Name                      Company  \
# 94     95  BE91A0bdcA49Bbc    Darrell   Douglas  Newton, Petersen and Mathis
#
#             City Country                Phone 1           Phone 2  \
# 94  Daisyborough    Mali  001-084-845-9524x1777  001-769-564-6303
#
#                        Email Subscription Date             Website
# 94  grayjean@lowery-good.com        2022-02-17  https://banks.biz/
