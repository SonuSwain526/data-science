# %%
import pandas as pd

# %%
df = pd.DataFrame({
 "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
 "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
 "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
 "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
 "Age": [23, 25, 30, 22, 28, 26, 21, 27],
 "JoinDate": pd.to_datetime([
      "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
 ])
    
 })
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby('Department')['Salary'].mean()
df.groupby('Department')['Salary'].sum()
df.groupby('Department')['Salary'].count()
df.groupby('Department')['Salary'].max()
df.groupby('Department')['Salary'].min()
# Out:
# Department
# HR           85
# IT           78
# Marketing    88
# Sales        75
# Name: Salary, dtype: int64

# %%
df.groupby(['Department', 'Team'])['Age'].max()
# Out:
# Department  Team
# HR          A       25
# IT          B       30
# Marketing   C       28
# Sales       D       27
# Name: Age, dtype: int64

# %%
df.groupby(['Department', 'Team'])['Salary'].agg(['min', 'max', 'mean'])
df.groupby(['Department', 'Team'])['Salary'].agg(average = "mean", maximum = "max", minmum = "min")
# df.groupby(['Department', 'Team']).agg({"Salary": "mean",
                                                  # "Age" : "max"          
                                                 # })
# Out:
#                  average  maximum  minmum
# Department Team
# HR         A        87.5       90      85
# IT         B        81.5       85      78
# Marketing  C        90.0       92      88
# Sales      D        77.5       80      75

# %%
df["salary mean"] = df.groupby('Department')['Salary'].transform("mean")

# %%
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate  salary mean
# 0         HR    A      M      85   23 2020-01-10         87.5
# 1         HR    A      F      90   25 2020-02-15         87.5
# 2         IT    B      M      78   30 2021-03-20         81.5
# 3         IT    B      F      85   22 2021-04-10         81.5
# 4  Marketing    C      M      92   28 2020-05-30         90.0
# 5  Marketing    C      F      88   26 2020-06-25         90.0
# 6      Sales    D      M      75   21 2021-07-15         77.5
# 7      Sales    D      F      80   27 2021-08-01         77.5

# %%
df.groupby('Department').filter(lambda x: (x['Salary']>85).any())
# Out:
#   Department Team Gender  Salary  Age   JoinDate  salary mean
# 0         HR    A      M      85   23 2020-01-10         87.5
# 1         HR    A      F      90   25 2020-02-15         87.5
# 4  Marketing    C      M      92   28 2020-05-30         90.0
# 5  Marketing    C      F      88   26 2020-06-25         90.0

# %%
df
