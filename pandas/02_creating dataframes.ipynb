# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# data freames from python list

# %%
data_list = [
    ["gourab", 40],
    ["asha", 50],
    ["deepa", 90]
            ]

df = pd.DataFrame(data_list)
df.columns = ["name", "mark"]

# %%
df
# Out:
#      name  mark
# 0  gourab    40
# 1    asha    50
# 2   deepa    90

# %% [markdown]
# data frames from dictionary lists

# %%
data_dict = {
 "Name": ["Alice", "Bob", "Charlie","Pinku"],
 "Age": [25, 30, 35, 0]
 }

df = pd.DataFrame(data_dict)
df
# Out:
#       Name Age
# 0    Alice  25
# 1      Bob  30
# 2  Charlie  35
# 3    Pinku

# %%
np_arr = np.array([[30, 40, 10], [100, 90, 99]])
df = pd.DataFrame(np_arr, columns = ["a", "b", "c"])
df
# Out:
#      a   b   c
# 0   30  40  10
# 1  100  90  99

# %% [markdown]
# by reading a csv file

# %%
df = pd.read_csv("customers-100.csv")
df_spesific_col = pd.read_csv("customers-100.csv", usecols = ["Customer Id", "Email"])
# df.columns
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df = pd.read_excel("Project-Management-Sample-Data.xlsx")
df
# Out:
#     Unnamed: 0               Unnamed: 1               Unnamed: 2   Unnamed: 3  \
# 0          NaN        Excel Sample Data                      NaN          NaN
# 1          NaN                      NaN                      NaN          NaN
# 2          NaN  Project Management Data                      NaN          NaN
# 3          NaN                      NaN                      NaN          NaN
# 4          NaN             Project Name                Task Name  Assigned to
# 5          NaN                Marketing          Market Research        Alice
# 6          NaN                Marketing         Content Creation          Bob
# 7          NaN                Marketing    Social Media Planning      Charlie
# 8          NaN                Marketing        Campaign Analysis        Daisy
# 9          NaN              Product Dev    Prototype Development        Ethan
# 10         NaN              Product Dev        Quality Assurance        Fiona
# ...

# %%
df = pd.read_json("jsondata.json")
df
# Out:
#                                                           user
# email                                  aarav.mehta@example.com
# hobbies                          [photography, cycling, chess]
# id                                                        1024
# last_login                                2025-08-29T10:15:00Z
# location     {'city': 'Mumbai', 'country': 'India', 'coordi...
# membership   {'status': 'active', 'tier': 'gold', 'renewal_...
# name                                               Aarav Mehta
# preferences  {'language': 'English', 'theme': 'dark', 'noti...
