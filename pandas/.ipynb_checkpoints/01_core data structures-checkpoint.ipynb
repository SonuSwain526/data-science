# %%
import pandas as pd

# %%
marks = pd.Series([12,40,33,60])

# %%
marks
# Out:
# 0    12
# 1    40
# 2    33
# 3    60
# dtype: int64

# %%
marks = pd.Series([12,40,33,60], index=["Gourab", "saer", "soname", "sreya"])
marks
# Out:
# Gourab    12
# saer      40
# soname    33
# sreya     60
# dtype: int64

# %%
marks["Gourab"]
# Out:
# 12

# %% [markdown]
# frames dat sets

# %%
data = {
    "Name" : ["Gourab", "saer", "soname", "sreya"],
    "age" : [18,30,27,14],
    "mark" : [12,40,33,18],
}

# %%
frame_Data = pd.DataFrame(data)
frame_Data
# Out:
#      Name  age  mark
# 0  Gourab   18    12
# 1    saer   30    40
# 2  soname   27    33
# 3   sreya   14    18

# %%
frame_Data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
frame_Data.columns
# Out:
# Index(['Name', 'age', 'mark'], dtype='object')

# %%
frame_Data.columns = ['naam', 'age', 'score']

# %%
frame_Data
# Out:
#      naam  age  score
# 0  Gourab   18     12
# 1    saer   30     40
# 2  soname   27     33
# 3   sreya   14     18
