# %%
import pandas as pd

# %%
df = pd.read_csv("products-100.csv")

# %%
df
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8      10               Ultra Powerbank Brush Charger Max
# 9       8                              Webcam Stove Grill
# 10      9                                       Eco Radio
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 14     12                                             NaN
# ...

# %%
df.isnull()
# Out:
#     Index   Name  Brand  Category  Price  Stock   Size  Internal ID
# 0   False  False  False     False  False  False  False        False
# 1   False  False  False     False   True  False  False        False
# 2   False  False  False     False   True  False  False        False
# 3   False  False  False     False  False  False  False        False
# 4   False  False  False     False  False  False  False        False
# 5   False  False  False     False  False  False  False        False
# 6   False  False  False     False  False  False  False        False
# 7   False  False  False     False  False  False  False        False
# 8   False  False   True     False  False  False  False        False
# 9   False  False  False     False  False  False  False        False
# 10  False  False   True     False  False  False  False        False
# 11  False  False  False     False  False  False  False        False
# 12  False  False  False     False  False  False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Index          0
# Name           2
# Brand          2
# Category       0
# Price          2
# Stock          0
# Size           0
# Internal ID    0
# dtype: int64

# %%
df.dropna()
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 9       8                              Webcam Stove Grill
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 15     13                                    Heater Radio
# 16     13                                    Heater Radio
# 17     14                     Smart Trimmer Webcam Heater
# 18     15                              Webcam Dock Heater
# 20     17                            Eco Iron Monitor Air
# ...

# %%
df.dropna(axis = 1)
# Out:
#     Index             Category  Stock         Size  Internal ID
# 0       1   Books & Stationery    774        Large           56
# 1       2     Shoes & Footwear     81      8x10 in           29
# 2       2     Shoes & Footwear     81      8x10 in           29
# 3       3   Kitchen Appliances    726           XS           70
# 4       4   Kitchen Appliances    896            L           31
# 5       5       Kids' Clothing    925   100x200 mm           10
# 6       6             Skincare    549     30x40 cm           60
# 7       7  Laptops & Computers    870            S           86
# 8      10    Fitness Equipment    564  Extra Large           88
# 9       8           Automotive    584      8x10 in           50
# 10      9             Skincare    499       Medium           88
# 11     10             Fitness    5964  Extra small           88
# 12     10    Fitness Equipment    564  Extra Large           88
# 13     11    Health & Wellness    168  Extra Large           30
# ...

# %% [markdown]
# fillingn null cells

# %%
df
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 8      10               Ultra Powerbank Brush Charger Max
# 9       8                              Webcam Stove Grill
# 10      9                                       Eco Radio
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 14     12                                             NaN
# ...

# %%
# df["Brand"] = df['Brand'].fillna("unknown brand")
# df
# df["Price"] = df["Price"].ffill() #one more thing is here bfill that fill the data accrodingly to the back data
df["Price"] = df["Price"].fillna(df['Price'].mean())
df['Price'].mean()
# Out:
# 347.1363636363637

# %% [markdown]
# playing with duplicate data

# %%
df.duplicated()
df.drop_duplicates()
df.duplicated(subset = ["Internal ID", "Category"])
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# dtype: bool

# %%
df["Category"].str.upper()
# df.at[2,"Category"].upper() #dont need to write str (that is for when you apply for hole clm)
# Out:
# 0      BOOKS & STATIONERY
# 1        SHOES & FOOTWEAR
# 2        SHOES & FOOTWEAR
# 3      KITCHEN APPLIANCES
# 4      KITCHEN APPLIANCES
# 5          KIDS' CLOTHING
# 6                SKINCARE
# 7     LAPTOPS & COMPUTERS
# 8       FITNESS EQUIPMENT
# 9              AUTOMOTIVE
# 10               SKINCARE
# 11               FITNESS
# 12      FITNESS EQUIPMENT
# 13      HEALTH & WELLNESS
# 14      CLEANING SUPPLIES
# 15                CYCLING
# 16                CYCLING
# 17             AUTOMOTIVE
# 18      CLEANING SUPPLIES
# 19            TEAM SPORTS
# 20             AUTOMOTIVE
# 21     BOOKS & STATIONERY
# 22      HEALTH & WELLNESS
# 23      CLEANING SUPPLIES
# Name: Category, dtype: object

# %% [markdown]
# we can also convert the type (typeconversesion)

# %%
df2 = df.dropna().copy()
df2["Price"].astype(int)
# Out:
# 0     265
# 1     347
# 2     347
# 3     227
# 4     121
# 5       1
# 6     426
# 7      68
# 9     159
# 11     84
# 12    845
# 13    257
# 15    689
# 16    689
# 17    279
# 18    101
# 20    982
# 21    265
# 22      3
# 23    340
# Name: Price, dtype: int32

# %%
df2
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 9       8                              Webcam Stove Grill
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 15     13                                    Heater Radio
# 16     13                                    Heater Radio
# 17     14                     Smart Trimmer Webcam Heater
# ...

# %%
df2["DOE"] = df2["Internal ID"].apply(lambda x: "10/10/2025" if x>50 else "10/10/2024")

# %%
df2
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 9       8                              Webcam Stove Grill
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 15     13                                    Heater Radio
# 16     13                                    Heater Radio
# 17     14                     Smart Trimmer Webcam Heater
# ...

# %%
df2["DOE"] = pd.to_datetime(df2["DOE"])

# %%
df2
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 9       8                              Webcam Stove Grill
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 15     13                                    Heater Radio
# 16     13                                    Heater Radio
# 17     14                     Smart Trimmer Webcam Heater
# ...

# %%
type(df2.iloc[2]["DOE"])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df2["Size"] = df2["Size"].replace({"L": "Large", "S": "Sort", "XS": "extra sort"})

# %%
df2
# Out:
#     Index                                            Name  \
# 0       1            Compact Printer Air Advanced Digital
# 1       2                                          Tablet
# 2       2                                          Tablet
# 3       3                            Smart Blender Cooker
# 4       4                    Advanced Router Rechargeable
# 5       5                    Portable Mouse Monitor Phone
# 6       6                                           Radio
# 7       7  Ultra Projector Oven Thermostat Prime Advanced
# 9       8                              Webcam Stove Grill
# 11     10               Ultra Powerbank Brush Charger Max
# 12     10               Ultra Powerbank Brush Charger Max
# 13     11                                   Wireless Dock
# 15     13                                    Heater Radio
# 16     13                                    Heater Radio
# 17     14                     Smart Trimmer Webcam Heater
# ...

# %%
df2.to_csv("df2 cleaned data.csv", index=False)
